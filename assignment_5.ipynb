# %%
#1. Given a list of numbers, write a python program that returns a new list which Has all 
#duplicate elements removed. And is sorted in an increasing order.
l=[2,1,3,4,2,3,3,2,7,9,8,7]
s=set(l)
l1=list(s)
l1.sort()
l1
# Out:
# [1, 2, 3, 4, 7, 8, 9]

# %%
#2. Write a Python program where you will iterate over both keys and values in dictionaries
d={"p1":2,"p2":3,"p3":4}
for keys,values in d.items():
    print(keys,values)
# Out:
# p1 2
# p2 3
# p3 4

# %%
#3. Write a Python program that takes a dictionary of student names and returns a list of 
#student names in alphabetical order
d={"student 1":"Tarun","Student 2":"Manoj","Student 3":"Gephi"}
l=[]
for v in d.values():
    l.append(v)
    l.sort()
print(l)
# Out:
# ['Gephi', 'Manoj', 'Tarun']

# %%
#4. Write a Python which returns a new list of Booleans, from a given number. Iterating 
#through the number one digit at a time, append True if the digit is 1 and False if it is 0.
i=input("enter your binary number")
l=[]
for x in i:
    if x=="1":
        l.append("True")
    elif x=="0":
        l.append("False")
        
print(l)
# Out:
# enter your binary number01011001
# ['False', 'True', 'False', 'True', 'True', 'False', 'False', 'True']

# %%
#5)Write a Python program where you will return a dictionary where the keys will be the
#character and the values will be the occurrence of the character in the string, and it 
#should for any string inputs (dynamic)
s=input("enter a string:")
l=list(s)
d={}
for i in l:
    d.update({i:s.count(i)})
del d[" "]
print(d)
# Out:
# enter a string:my name is amy
# {'m': 3, 'y': 2, 'n': 1, 'a': 2, 'e': 1, 'i': 1, 's': 1}

# %%
#6. Given a dictionary containing the names and ages of a group of people, return the 
#name of the oldest person
n={"Tmma": 41, "Ackes": 45, "myna": 15, "Benthon": 29}
l=list(n.values())
l.sort()
great=l[-1]
for keys,values in n.items():
    if n[keys]==great:
        print(keys)
# Out:
# Ackes

# %%
#7. Write a Python program to create a Rock, Paper, Scissor game, use two inputs for two players:
pick1=input("pick any of these rock,paper,scissors: ")
pick2=input("pick any of these rock,paper,scissors: ")
if pick1=="rock" and pick2=="paper":
    print("paper has won over rock")
elif pick1=="rock" and pick2=="scissors":
    print("rock has won over scissors")
elif pick1=="rock" and pick2=="rock":
    print("nobody has won")
elif pick1=="paper" and pick2=="scissors":
    print("scissors has won over paper")
elif pick1=="paper" and pick2=="rock":
    print("paper has won over rock")
elif pick1=="paper" and pick2=="paper":
    print("nobody has won")
elif pick1=="scissors" and pick2=="rock":
    print("rock has won over scissors")
elif pick1=="scissors" and pick2=="paper":
    print("scissors has won over paper")
elif pick1=="scissors" and pick2=="scissors":
    print("nobody has won")
else:
    print("error")
# Out:
# pick any of these rock,paper,scissors: rock
# pick any of these rock,paper,scissors: paper
# paper has won over rock

# %%
#8. Create a program that returns a list of items that you can afford in the store with the 
#money you have in your wallet. Create a dictionary with items as key and price as values
supplies={"water bottles":20,"chips":10,"Iphone":49000,"towel":90,"pens":58,"cake":400}
money=int(input("enter your wallet balance : "))
l=[]
for keys,values in supplies.items():
    if values<=money:
        l.append(keys)
    else:
        continue
print(l)
# Out:
# enter your wallet balance : 50
# ['water bottles', 'chips']

# %%
#9. Write a Python program to create a union of sets
s1={1,2,3,4,5,6}
s2={9,3,2,5,66,7}
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 66}

# %%
#10. Write a Python program to check if a given value is present in a set or not (Dynamic)
s=set()
l=int(input("enter your set length :"))
for i in range(1,l):
    n=int(input("enter a number :"))
    s.add(n)
v=input("enter a number to check whether it is list or not  :")
if int(v) in s :
     print("the given number is present in the set")
else:
     print("the given number doesn't present in the set")
# Out:
# enter your set length :7
# enter a number :2
# enter a number :3
# enter a number :4
# enter a number :5
# enter a number :6
# enter a number :7
# enter a number to check whether it is list or not  :2
# the given number is present in the set

# %%
#11. Write a Python program to find the occurrences of 3 most common words in a 
#given text. And make it as a dictionaries
s=input("enter a string")
c=s.split()
d={}
for i in c:
    d[i]=s.count(i)
l2=list(d.values())
l2.sort()
l3=l2[-3:]
d1={}
for keys,values in d.items():
    if values in l3:
        d1.update({keys:values})
print(d1)
# Out:
# enter a stringcat dog dog cat horse dog dog mouse horse dog mouse tiger lion tiger cat mouse snail
# {'cat': 3, 'dog': 5, 'mouse': 3}

# %%
#12. Write a Python program that accepts name of given subject and mark, and 
#make subjects as keys in dictionaries and marks as values and print the final
#dictionary with subjects and marks
l=int(input("enter your dictionary length : "))
d={}
for i in range(l):
    n=input("name of given subject : ")
    m=int(input("marks in the given subject : "))
    d.update({n:m})
print(d)
# Out:
# enter your dictionary length : 6
# name of given subject : math
# marks in the given subject : 100
# name of given subject : science
# marks in the given subject : 98
# name of given subject : social
# marks in the given subject : 98
# name of given subject : english
# marks in the given subject : 97
# name of given subject : it
# marks in the given subject : 96
# name of given subject : physics
# marks in the given subject : 89
# {'math': 100, 'science': 98, 'social': 98, 'english': 97, 'it': 96, 'physics': 89}
