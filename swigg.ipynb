# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd

# %%
url="https://www.swiggy.com/city/bangalore/south-indian-collection?page=8"

# %%
page=requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
## Bangalore-df

# %% [markdown]
# Restaurant,Cuisine,Coupon,Rating,Delivered_in,Budget,People

# %%
restaurant=[]
cuisine=[]
coupon=[]
rating=[]
delivered_in=[]
budget=[]
people=[]
for i in range(1,9):
    url="https://www.swiggy.com/city/bangalore/south-indian-collection?page="+str(i)
    print(url)
    page=requests.get(url)
    soup=BeautifulSoup(page.content)
    a= soup.find_all('div', class_="nA6kb")
    for i in a:
        restaurant.append(i.text)
    b= soup.find_all('div', class_="_1gURR")
    for i in b:
        cuisine.append(i.text)    
    d= soup.find_all('span', class_="sNAfh")
    for i in d:
        coupon.append(i.text)
    
    e=soup.find_all('div', class_="_3Mn31")
    for i in e:
        rating.append(i.text.split("•")[0])
        delivered_in.append(i.text.split("•")[1].split(" ")[0])
        budget.append(i.text.split("₹")[1].split(" ")[0])
        people.append(i.text.split("₹")[1].split(" ")[2])
        
print(len(restaurant))
print(len(cuisine))
print(len(coupon))
print(len(rating))
print(len(delivered_in))
print(len(budget))
print(len(people))
# Out:
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=1
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=2
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=3
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=4
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=5
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=6
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=7
# https://www.swiggy.com/city/bangalore/south-indian-collection?page=8
# 128
# 128
# 130
# 128
# 128
# 128
# 128

# %%
df=pd.DataFrame({'Restaurant':restaurant, 'Cuisine':cuisine, 'Coupon':coupon[0:128], 'rating':rating,"delivered_in":delivered_in,"budget":budget,"people":people})

# %%
df
# Out:
#                        Restaurant  \
# 0                   Meghana Foods
# 1                       Soul Rasa
# 2                 Ayodhya Upachar
# 3                Puliyogare Point
# 4              N R Donne Biriyani
# ..                            ...
# 123            Lakshmi food point
# 124                   Mayura 1989
# 125                     Bob's Bar
# 126  SLV Swadishta (South Indian)
# 127                   By 2 Coffee
#
#                                                Cuisine  \
# 0    Biryani, Andhra, South Indian, North Indian, C...
# 1    Indian, Healthy Food, Home Food, South Indian,...
# 2    Chinese, Desserts, North Indian, South Indian,...
# 3                                         South Indian
# 4                                Biryani, South Indian
# ..                                                 ...
# 123                               South Indian, Indian
# 124  Chinese, South Indian, North Indian, Desserts,...
# ...

# %%
#hyd=df2

# %%
url1="https://www.swiggy.com/city/hyderabad/south-indian-collection"

# %%
page=requests.get(url1)

# %%
page
# Out:
# <Response [200]>

# %%
restaurant=[]
cuisine=[]
coupon=[]
rating=[]
delivered_in=[]
budget=[]
people=[]
for i in range(1,9):
    url="https://www.swiggy.com/city/hyderabad/south-indian-collection?page="+str(i)
    print(url)
    page=requests.get(url)
    soup=BeautifulSoup(page.content)
    a= soup.find_all('div', class_="nA6kb")
    for i in a:
        restaurant.append(i.text)
    b= soup.find_all('div', class_="_1gURR")
    for i in b:
        cuisine.append(i.text)    
    d= soup.find_all('span', class_="sNAfh")
    for i in d:
        coupon.append(i.text)
    
    e=soup.find_all('div', class_="_3Mn31")
    for i in e:
        rating.append(i.text.split("•")[0])
        delivered_in.append(i.text.split("•")[1].split(" ")[0])
        budget.append(i.text.split("₹")[1].split(" ")[0])
        people.append(i.text.split("₹")[1].split(" ")[2])
        
print(len(restaurant))
print(len(cuisine))
print(len(coupon))
print(len(rating))
print(len(delivered_in))
print(len(budget))
print(len(people))
# Out:
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=1
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=2
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=3
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=4
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=5
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=6
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=7
# https://www.swiggy.com/city/hyderabad/south-indian-collection?page=8
# 128
# 128
# 131
# 128
# 128
# 128
# 128

# %%
df2=pd.DataFrame({'Restaurant':restaurant, 'Cuisine':cuisine, 'Coupon':coupon[0:128], 'rating':rating,"delivered_in":delivered_in,"budget":budget,"people":people})

# %%
df2
# Out:
#                          Restaurant  \
# 0             Vasista's Sri Lakshmi
# 1     Lucky Multicuisine Restaurant
# 2                 Vivaha Bhojanambu
# 3                 Meghduth Biryanis
# 4               Subbayya Gari Hotel
# ..                              ...
# 123                South by Cravery
# 124   Shree Meghana Foods Take Away
# 125            Anjali Tiffin Center
# 126       JAITHRI'S SARAVANA BHAVAN
# 127  B Curries (by Biryanis & More)
#
#                                                Cuisine  \
# 0    Biryani, Tandoor, Chinese, North Indian, South...
# 1         Biryani, North Indian, Tandoor, South Indian
# 2      South Indian, Biryani, Andhra, Chinese, Tandoor
# 3               Biryani, Chinese, Andhra, South Indian
# 4                         South Indian, Andhra, Sweets
# ..                                                 ...
# 123                                       South Indian
# 124           Chinese, Indian, South Indian, Home Food
# ...

# %%
#chennai=df3

# %%
url2="https://www.swiggy.com/city/chennai/south-indian-collection"

# %%
page=requests.get(url2)

# %%
page
# Out:
# <Response [200]>

# %%
restaurant=[]
cuisine=[]
coupon=[]
rating=[]
delivered_in=[]
budget=[]
people=[]
for i in range(1,9):
    url="https://www.swiggy.com/city/chennai/south-indian-collection?page="+str(i)
    print(url)
    page=requests.get(url)
    soup=BeautifulSoup(page.content)
    a= soup.find_all('div', class_="nA6kb")
    for i in a:
        restaurant.append(i.text)
    b= soup.find_all('div', class_="_1gURR")
    for i in b:
        cuisine.append(i.text)    
    d= soup.find_all('span', class_="sNAfh")
    for i in d:
        coupon.append(i.text)
    
    e=soup.find_all('div', class_="_3Mn31")
    for i in e:
        rating.append(i.text.split("•")[0])
        delivered_in.append(i.text.split("•")[1].split(" ")[0])
        budget.append(i.text.split("₹")[1].split(" ")[0])
        people.append(i.text.split("₹")[1].split(" ")[2])
        
print(len(restaurant))
print(len(cuisine))
print(len(coupon))
print(len(rating))
print(len(delivered_in))
print(len(budget))
print(len(people))
# Out:
# https://www.swiggy.com/city/chennai/south-indian-collection?page=1
# https://www.swiggy.com/city/chennai/south-indian-collection?page=2
# https://www.swiggy.com/city/chennai/south-indian-collection?page=3
# https://www.swiggy.com/city/chennai/south-indian-collection?page=4
# https://www.swiggy.com/city/chennai/south-indian-collection?page=5
# https://www.swiggy.com/city/chennai/south-indian-collection?page=6
# https://www.swiggy.com/city/chennai/south-indian-collection?page=7
# https://www.swiggy.com/city/chennai/south-indian-collection?page=8
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
df3=pd.DataFrame({'Restaurant':restaurant, 'Cuisine':cuisine, 'Coupon':coupon, 'rating':rating,"delivered_in":delivered_in,"budget":budget,"people":people})

# %%
df3
# Out:
#                                  Restaurant  \
# 0               Shero Home Food - Chettinad
# 1                           New Milan Hotel
# 2                             Kovai Kitchen
# 3                  Sangeetha Veg Restaurant
# 4                               Naattarasan
# 5                                MS Biryani
# 6                       Ar rahaman biriyani
# 7                     hotel sri devi bhavan
# 8                                 GRK HOTEL
# 9                         NITHYA HOME FOODS
# 10  ARASAMPATTI CHETTINAD FAMILY RESTAURANT
# 11                Shree Iyyah's Annabrahmam
# 12                           Siddhu Kitchen
# 13                   Loiee's veg restaurant
# 14         S V Homemade Gourmet Food Corner
# 15                  Hotel Royal Food Corner
# 16                      Divya Tiffin Center
# 17                  SRM Chettinadu Unavagam
# 18                           The bamboo Hut
# 19                 Sivasakthi Tiffin Centre
#
# ...

# %%
#noida-1=df4

# %%
url3="https://www.swiggy.com/city/noida-1"

# %%
page=requests.get(url3)

# %%
page
# Out:
# <Response [200]>

# %%
restaurant=[]
cuisine=[]
coupon=[]
rating=[]
delivered_in=[]
budget=[]
people=[]
for i in range(1,9):
    url="https://www.swiggy.com/city/noida-1?page="+str(i)
    print(url)
    page=requests.get(url)
    soup=BeautifulSoup(page.content)
    a= soup.find_all('div', class_="nA6kb")
    for i in a:
        restaurant.append(i.text)
    b= soup.find_all('div', class_="_1gURR")
    for i in b:
        cuisine.append(i.text)    
    d= soup.find_all('span', class_="sNAfh")
    for i in d:
        coupon.append(i.text)
    
    e=soup.find_all('div', class_="_3Mn31")
    for i in e:
        rating.append(i.text.split("•")[0])
        delivered_in.append(i.text.split("•")[1].split(" ")[0])
        budget.append(i.text.split("₹")[1].split(" ")[0])
        people.append(i.text.split("₹")[1].split(" ")[2])
        
print(len(restaurant))
print(len(cuisine))
print(len(coupon))
print(len(rating))
print(len(delivered_in))
print(len(budget))
print(len(people))
# Out:
# https://www.swiggy.com/city/noida-1?page=1
# https://www.swiggy.com/city/noida-1?page=2
# https://www.swiggy.com/city/noida-1?page=3
# https://www.swiggy.com/city/noida-1?page=4
# https://www.swiggy.com/city/noida-1?page=5
# https://www.swiggy.com/city/noida-1?page=6
# https://www.swiggy.com/city/noida-1?page=7
# https://www.swiggy.com/city/noida-1?page=8
# 128
# 128
# 130
# 128
# 128
# 128
# 128

# %%
df4=pd.DataFrame({'Restaurant':restaurant, 'Cuisine':cuisine, 'Coupon':coupon[0:128], 'rating':rating,"delivered_in":delivered_in,"budget":budget,"people":people})

# %%
df4
# Out:
#                        Restaurant  \
# 0                             KFC
# 1                        Nirula's
# 2                    Simply South
# 3       Chaayos Chai+Snacks=Relax
# 4               Khan's Kathi Roll
# ..                            ...
# 123      Veer Ji Malai Chaap Wale
# 124                   Bikanervala
# 125                  Shri Gokulam
# 126                       Buraans
# 127  Aalam Chicken Biryani Center
#
#                                                Cuisine  \
# 0        Burgers, Biryani, American, Snacks, Fast Food
# 1    Desserts, Ice Cream, Beverages, Ice Cream Cake...
# 2                                         South Indian
# 3    Bakery, Beverages, Chaat, Desserts, Fast Food,...
# 4                          Chinese, Beverages, Mughlai
# ..                                                 ...
# 123                                       North Indian
# 124  North Indian, South Indian, Chinese, Sweets, F...
# ...

# %%
v=pd.concat([df,df2,df3,df4],axis=0)

# %%
v=v.reset_index(drop=True)

# %%
v
# Out:
#                                     Restaurant  \
# 0                                Meghana Foods
# 1                             Puliyogare Point
# 2                              Ayodhya Upachar
# 3                            Hotel Kadamba Veg
# 4    Chikpet Donne Biryani House - Vijayanagar
# ..                                         ...
# 399                   Veer Ji Malai Chaap Wale
# 400                                Bikanervala
# 401                               Shri Gokulam
# 402                                    Buraans
# 403               Aalam Chicken Biryani Center
#
#                                                Cuisine  \
# 0    Biryani, Andhra, South Indian, North Indian, C...
# 1                                         South Indian
# 2    Chinese, Desserts, North Indian, South Indian,...
# 3          South Indian, North Indian, Chinese, Sweets
# 4                                Biryani, South Indian
# ..                                                 ...
# ...

# %%
v.shape
# Out:
# (404, 7)

# %%
v.to_csv('swiggy_up.csv')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mandl\\Downloads'

# %%
city=["Banglore"]
k=128
l=[]
for i in city:
    for j in range(k):
        l.append(i)
print(l)
# Out:
# ['Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', '
# ...

# %%
Location=['Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore', 'Banglore']
df["Location"]=Location

# %%
df
# Out:
#                                     Restaurant  \
# 0                                Meghana Foods
# 1                             Puliyogare Point
# 2                              Ayodhya Upachar
# 3                            Hotel Kadamba Veg
# 4    Chikpet Donne Biryani House - Vijayanagar
# ..                                         ...
# 123                           SRI BRAHMI RUCHI
# 124                                  Bob's Bar
# 125                   Udupi Sri Krishna Bhavan
# 126                          SOUTH HOLIGE MANE
# 127                        South Ruchis Square
#
#                                                Cuisine  \
# 0    Biryani, Andhra, South Indian, North Indian, C...
# 1                                         South Indian
# 2    Chinese, Desserts, North Indian, South Indian,...
# 3          South Indian, North Indian, Chinese, Sweets
# 4                                Biryani, South Indian
# ..                                                 ...
# ...

# %%
city=["Hyderabad"]
k=128
l=[]
for i in city:
    for j in range(k):
        l.append(i)
print(l)
# Out:
# ['Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderaba
# ...

# %%
Location=['Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad', 'Hyderabad']
df2["Location"]=Location

# %%
df2
# Out:
#                          Restaurant  \
# 0             Vasista's Sri Lakshmi
# 1     Lucky Multicuisine Restaurant
# 2                 Vivaha Bhojanambu
# 3                 Meghduth Biryanis
# 4               Subbayya Gari Hotel
# ..                              ...
# 123                South by Cravery
# 124   Shree Meghana Foods Take Away
# 125            Anjali Tiffin Center
# 126       JAITHRI'S SARAVANA BHAVAN
# 127  B Curries (by Biryanis & More)
#
#                                                Cuisine  \
# 0    Biryani, Tandoor, Chinese, North Indian, South...
# 1         Biryani, North Indian, Tandoor, South Indian
# 2      South Indian, Biryani, Andhra, Chinese, Tandoor
# 3               Biryani, Chinese, Andhra, South Indian
# 4                         South Indian, Andhra, Sweets
# ..                                                 ...
# 123                                       South Indian
# 124           Chinese, Indian, South Indian, Home Food
# ...

# %%
city=["Chennai"]
k=20
l=[]
for i in city:
    for j in range(k):
        l.append(i)
print(l)
# Out:
# ['Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai']

# %%
Location=['Chennai','Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai', 'Chennai']
df3["Location"]=Location
df3
# Out:
#                                  Restaurant  \
# 0               Shero Home Food - Chettinad
# 1                           New Milan Hotel
# 2                             Kovai Kitchen
# 3                  Sangeetha Veg Restaurant
# 4                               Naattarasan
# 5                                MS Biryani
# 6                       Ar rahaman biriyani
# 7                     hotel sri devi bhavan
# 8                                 GRK HOTEL
# 9                         NITHYA HOME FOODS
# 10  ARASAMPATTI CHETTINAD FAMILY RESTAURANT
# 11                Shree Iyyah's Annabrahmam
# 12                           Siddhu Kitchen
# 13                   Loiee's veg restaurant
# 14         S V Homemade Gourmet Food Corner
# 15                  Hotel Royal Food Corner
# 16                      Divya Tiffin Center
# 17                  SRM Chettinadu Unavagam
# 18                           The bamboo Hut
# 19                 Sivasakthi Tiffin Centre
#
# ...

# %%
city=["Noida1"]
k=128
l=[]
for i in city:
    for j in range(k):
        l.append(i)
print(l)
# Out:
# ['Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1
# ...

# %%
Location=['Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1', 'Noida1']
df4["Location"]=Location

# %%
df4
# Out:
#                        Restaurant  \
# 0                             KFC
# 1                        Nirula's
# 2                    Simply South
# 3       Chaayos Chai+Snacks=Relax
# 4               Khan's Kathi Roll
# ..                            ...
# 123      Veer Ji Malai Chaap Wale
# 124                   Bikanervala
# 125                  Shri Gokulam
# 126                       Buraans
# 127  Aalam Chicken Biryani Center
#
#                                                Cuisine  \
# 0        Burgers, Biryani, American, Snacks, Fast Food
# 1    Desserts, Ice Cream, Beverages, Ice Cream Cake...
# 2                                         South Indian
# 3    Bakery, Beverages, Chaat, Desserts, Fast Food,...
# 4                          Chinese, Beverages, Mughlai
# ..                                                 ...
# 123                                       North Indian
# 124  North Indian, South Indian, Chinese, Sweets, F...
# ...

# %%
f=pd.concat([df,df2,df3,df4],axis=0)
f.reset_index(drop=True)
# Out:
#                                     Restaurant  \
# 0                                Meghana Foods
# 1                             Puliyogare Point
# 2                              Ayodhya Upachar
# 3                            Hotel Kadamba Veg
# 4    Chikpet Donne Biryani House - Vijayanagar
# ..                                         ...
# 399                   Veer Ji Malai Chaap Wale
# 400                                Bikanervala
# 401                               Shri Gokulam
# 402                                    Buraans
# 403               Aalam Chicken Biryani Center
#
#                                                Cuisine  \
# 0    Biryani, Andhra, South Indian, North Indian, C...
# 1                                         South Indian
# 2    Chinese, Desserts, North Indian, South Indian,...
# 3          South Indian, North Indian, Chinese, Sweets
# 4                                Biryani, South Indian
# ..                                                 ...
# ...

# %%
f.iloc[:,[0,7,1,2,3,4,5,6]]
# Out:
#                                     Restaurant  Location  \
# 0                                Meghana Foods  Banglore
# 1                             Puliyogare Point  Banglore
# 2                              Ayodhya Upachar  Banglore
# 3                            Hotel Kadamba Veg  Banglore
# 4    Chikpet Donne Biryani House - Vijayanagar  Banglore
# ..                                         ...       ...
# 123                   Veer Ji Malai Chaap Wale    Noida1
# 124                                Bikanervala    Noida1
# 125                               Shri Gokulam    Noida1
# 126                                    Buraans    Noida1
# 127               Aalam Chicken Biryani Center    Noida1
#
#                                                Cuisine  \
# 0    Biryani, Andhra, South Indian, North Indian, C...
# 1                                         South Indian
# 2    Chinese, Desserts, North Indian, South Indian,...
# ...
